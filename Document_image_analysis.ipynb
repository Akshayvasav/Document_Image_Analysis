# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r"C:\Program Files\Tesseract-OCR\tesseract.exe"
import fileinput
import re

# %%
img = cv2.imread(r"E:\Data Science\open_internship\Pancard_Tanwi.JPEG")
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# a eS
#
# _ / Name
# TANWI VIJAY PATHAK
#
# faa HT Aa / Father's Name
# VIJAY VINAYAK PATHAK
#
# =a at atthe / Date of Birth
# 07/09/1997 —
#
#
#
#
# Permanent Account Number Card ©
#
# DOMPP3891D
#
# BeMAr/ Signature

# %%
f = open(r"E:\Data Science\open_internship\Akshay_pancard.txt", "w")   # 'r' for reading and 'w' for writing
f.write(text)
f.close()

# %%
lines = text.split("\n")
non_empty_lines = [line for line in lines if line.strip() != ""]

string_without_empty_lines = ""
for line in non_empty_lines:
      string_without_empty_lines += line + "\n"
print( string_without_empty_lines)
# Out:
# a eS
# _ / Name
# TANWI VIJAY PATHAK
# faa HT Aa / Father's Name
# VIJAY VINAYAK PATHAK
# =a at atthe / Date of Birth
# 07/09/1997 —
# Permanent Account Number Card ©
# DOMPP3891D
# BeMAr/ Signature

# %%
lines = text.split("\n")
#print(lines)
non_empty_lines = []
for line in lines:
    if line.strip() != "":
        non_empty_lines.append(line)
list_lnfo = []
for i in range(len(non_empty_lines)):
    if len(non_empty_lines[i]) !=0:
        list_lnfo.append(non_empty_lines[i])
list_lnfo
        
# string_without_empty_lines = ""
# for line in non_empty_lines:
#       string_without_empty_lines += line + "\n"
# print( string_without_empty_lines)
# Out:
# ['a eS',
#  '_ / Name',
#  'TANWI VIJAY PATHAK',
#  "faa HT Aa / Father's Name",
#  'VIJAY VINAYAK PATHAK',
#  '=a at atthe / Date of Birth',
#  '07/09/1997 —',
#  'Permanent Account Number Card ©',
#  'DOMPP3891D',
#  'BeMAr/ Signature']

# %%
bad_chars = ['_','—', '/', "=","@"]
final_list =[]
for p in range(len(list_lnfo)):
    # initializing test string
    test_string = list_lnfo[p]
    for i in bad_chars :
        test_string = test_string.replace(i, '')
    final_list.append(test_string)
print(final_list)
# Out:
# ['a eS', '  Name', 'TANWI VIJAY PATHAK', "faa HT Aa  Father's Name", 'VIJAY VINAYAK PATHAK', 'a at atthe  Date of Birth', '07091997 ', 'Permanent Account Number Card ©', 'DOMPP3891D', 'BeMAr Signature']

# %%
#to grab Pan number
final_info = []
final_dict ={}
sub_str ="Permanent Account Number"
for i in range(len(list_lnfo)):
    if (list_lnfo[i].find(sub_str) != -1):
        final_info.append("Permanent Account Number")
        final_info.append(list_lnfo[i+1])
        #final_dict.append(list_lnfo[i+1])
final_info
#final_dict
# Out:
# ['Permanent Account Number', 'DOMPP3891D']

# %%
#to grab Date of Birth
person_info = {}
dob =["Date of Birth","Father's Name","Name","Permanent Account Number"]
for i in dob:
    #print(i)
    for j in range(len(final_list)):
        if (final_list[j].find(i) != -1):
            #print(final_list[j])
            person_info.update({i:final_list[j+1]})
print(person_info)
# Out:
# {'Date of Birth': '07091997 ', "Father's Name": 'VIJAY VINAYAK PATHAK', 'Name': 'VIJAY VINAYAK PATHAK', 'Permanent Account Number': 'DOMPP3891D'}
